# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("loan 2.csv")
# Out:
# /var/folders/qc/gk_jrz1s3ln3dwkfp1yhtc3h0000gq/T/ipykernel_70562/153529759.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("loan 2.csv")

# %%
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# 0       36 months   10.65%       162.87     B        B2  ...
# 1       60 months   15.27%        59.83     C        C4  ...
# 2       36 months   15.96%        84.33     C        C5  ...
# 3       36 months   13.49%       339.31     C        C1  ...
# 4       60 months   12.69%        67.79     B        B5  ...
# ...           ...      ...          ...   ...       ...  ...
# 39712   36 months    8.07%        78.42     A        A4  ...
# 39713   36 months   10.28%       275.38     C        C1  ...
# 39714   36 months    8.07%       156.84     A        A4  ...
# 39715   36 months    7.43%       155.38     A        A2  ...
# 39716   36 months   13.75%       255.43     E        E2  ...
#
#       num_tl_90g_dpd_24m num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75  \
# 0                    NaN                NaN            NaN               NaN
# 1                    NaN                NaN            NaN               NaN
# 2                    NaN                NaN            NaN               NaN
# 3                    NaN                NaN            NaN               NaN
# 4                    NaN                NaN            NaN               NaN
# ...                  ...                ...            ...               ...
# 39712                NaN                NaN            NaN               NaN
# 39713                NaN                NaN            NaN               NaN
# 39714                NaN                NaN            NaN               NaN
# 39715                NaN                NaN            NaN               NaN
# 39716                NaN                NaN            NaN               NaN
#
#       pub_rec_bankruptcies tax_liens tot_hi_cred_lim total_bal_ex_mort  \
# 0                      0.0       0.0             NaN               NaN
# 1                      0.0       0.0             NaN               NaN
# 2                      0.0       0.0             NaN               NaN
# 3                      0.0       0.0             NaN               NaN
# 4                      0.0       0.0             NaN               NaN
# ...                    ...       ...             ...               ...
# 39712                  NaN       NaN             NaN               NaN
# 39713                  NaN       NaN             NaN               NaN
# 39714                  NaN       NaN             NaN               NaN
# 39715                  NaN       NaN             NaN               NaN
# 39716                  NaN       NaN             NaN               NaN
#
#       total_bc_limit total_il_high_credit_limit
# 0                NaN                        NaN
# 1                NaN                        NaN
# 2                NaN                        NaN
# 3                NaN                        NaN
# 4                NaN                        NaN
# ...              ...                        ...
# 39712            NaN                        NaN
# 39713            NaN                        NaN
# 39714            NaN                        NaN
# 39715            NaN                        NaN
# 39716            NaN                        NaN
#
# [39717 rows x 111 columns]

# %%
df.iloc[:,:].isna().sum()
# below we can see some columns has completely NAN data, we can clean that
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
df.replace(0, np.nan, inplace=True)
# in dataframe there are columns which have 0 values, some columns has combination of 0 and NA value,
# we can replace 0 with NA and drop those columns

# %%
df = df.dropna(axis=1, how='all')

# %%
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# 0       36 months   10.65%       162.87     B        B2  ...
# 1       60 months   15.27%        59.83     C        C4  ...
# 2       36 months   15.96%        84.33     C        C5  ...
# 3       36 months   13.49%       339.31     C        C1  ...
# 4       60 months   12.69%        67.79     B        B5  ...
# ...           ...      ...          ...   ...       ...  ...
# 39712   36 months    8.07%        78.42     A        A4  ...
# 39713   36 months   10.28%       275.38     C        C1  ...
# 39714   36 months    8.07%       156.84     A        A4  ...
# 39715   36 months    7.43%       155.38     A        A2  ...
# 39716   36 months   13.75%       255.43     E        E2  ...
#
#       total_rec_late_fee recoveries collection_recovery_fee  last_pymnt_d  \
# 0                    NaN        NaN                     NaN        Jan-15
# 1                    NaN     117.08                    1.11        Apr-13
# 2                    NaN        NaN                     NaN        Jun-14
# 3                  16.97        NaN                     NaN        Jan-15
# 4                    NaN        NaN                     NaN        May-16
# ...                  ...        ...                     ...           ...
# 39712                NaN        NaN                     NaN        Jul-10
# 39713                NaN        NaN                     NaN        Jul-10
# 39714                NaN        NaN                     NaN        Apr-08
# 39715                NaN        NaN                     NaN        Jan-08
# 39716                NaN        NaN                     NaN        Jun-10
#
#       last_pymnt_amnt next_pymnt_d last_credit_pull_d policy_code  \
# 0              171.62          NaN             May-16           1
# 1              119.66          NaN             Sep-13           1
# 2              649.91          NaN             May-16           1
# 3              357.48          NaN             Apr-16           1
# 4               67.79       Jun-16             May-16           1
# ...               ...          ...                ...         ...
# 39712           80.90          NaN             Jun-10           1
# 39713          281.94          NaN             Jul-10           1
# 39714             NaN          NaN             Jun-07           1
# 39715             NaN          NaN             Jun-07           1
# 39716          256.59          NaN             Jun-10           1
#
#       application_type pub_rec_bankruptcies
# 0           INDIVIDUAL                  NaN
# 1           INDIVIDUAL                  NaN
# 2           INDIVIDUAL                  NaN
# 3           INDIVIDUAL                  NaN
# 4           INDIVIDUAL                  NaN
# ...                ...                  ...
# 39712       INDIVIDUAL                  NaN
# 39713       INDIVIDUAL                  NaN
# 39714       INDIVIDUAL                  NaN
# 39715       INDIVIDUAL                  NaN
# 39716       INDIVIDUAL                  NaN
#
# [39717 rows x 52 columns]

# %%
df.iloc[:,:].isna().sum()
# Out:
# id                             0
# member_id                      0
# loan_amnt                      0
# funded_amnt                    0
# funded_amnt_inv              129
# term                           0
# int_rate                       0
# installment                    0
# grade                          0
# sub_grade                      0
# emp_title                   2459
# emp_length                  1075
# home_ownership                 0
# annual_inc                     0
# verification_status            0
# issue_d                        0
# loan_status                    0
# pymnt_plan                     0
# url                            0
# desc                       12940
# purpose                        0
# title                         11
# zip_code                       0
# addr_state                     0
# dti                          183
# delinq_2yrs                35405
# earliest_cr_line               0
# inq_last_6mths             19300
# mths_since_last_delinq     26125
# mths_since_last_record     37601
# open_acc                       0
# pub_rec                    37601
# revol_bal                    994
# revol_util                    50
# total_acc                      0
# initial_list_status            0
# out_prncp                  38577
# out_prncp_inv              38577
# total_pymnt                   16
# total_pymnt_inv              165
# total_rec_prncp               74
# total_rec_int                 71
# total_rec_late_fee         37671
# recoveries                 35499
# collection_recovery_fee    35935
# last_pymnt_d                  71
# last_pymnt_amnt               74
# next_pymnt_d               38577
# last_credit_pull_d             2
# policy_code                    0
# application_type               0
# pub_rec_bankruptcies       38036
# dtype: int64

# %%
# check if there is any duplicate row
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, member_id, loan_amnt, funded_amnt, funded_amnt_inv, term, int_rate, installment, grade, sub_grade, emp_title, emp_length, home_ownership, annual_inc, verification_status, issue_d, loan_status, pymnt_plan, url, desc, purpose, title, zip_code, addr_state, dti, delinq_2yrs, earliest_cr_line, inq_last_6mths, mths_since_last_delinq, mths_since_last_record, open_acc, pub_rec, revol_bal, revol_util, total_acc, initial_list_status, out_prncp, out_prncp_inv, total_pymnt, total_pymnt_inv, total_rec_prncp, total_rec_int, total_rec_late_fee, recoveries, collection_recovery_fee, last_pymnt_d, last_pymnt_amnt, next_pymnt_d, last_credit_pull_d, policy_code, application_type, pub_rec_bankruptcies]
# Index: []
#
# [0 rows x 52 columns]

# %%
# drop row which has NA in all columns
df.dropna(how='all',inplace=True)
# Out:
# /var/folders/qc/gk_jrz1s3ln3dwkfp1yhtc3h0000gq/T/ipykernel_70562/857103075.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(how='all',inplace=True)

# %%
df.shape
# Out:
# (39717, 52)

# %%
# dropping uneccesary columns
df.drop(["id","member_id","url","emp_title", "desc", "purpose", "title", "zip_code", "addr_state", "next_pymnt_d", "mths_since_last_record", "policy_code","pymnt_plan", "initial_list_status","pub_rec","delinq_2yrs","out_prncp","out_prncp_inv","total_rec_late_fee","recoveries","collection_recovery_fee","pub_rec_bankruptcies","inq_last_6mths","mths_since_last_delinq"], axis=1, inplace=True)
# Out:
# /var/folders/qc/gk_jrz1s3ln3dwkfp1yhtc3h0000gq/T/ipykernel_70562/3579454275.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(["id","member_id","url","emp_title", "desc", "purpose", "title", "zip_code", "addr_state", "next_pymnt_d", "mths_since_last_record", "policy_code","pymnt_plan", "initial_list_status","pub_rec","delinq_2yrs","out_prncp","out_prncp_inv","total_rec_late_fee","recoveries","collection_recovery_fee","pub_rec_bankruptcies","inq_last_6mths","mths_since_last_delinq"], axis=1, inplace=True)

# %%
df.shape
# Out:
# (39717, 28)

# %%
df.iloc[:,:].isna().sum()
# Out:
# loan_amnt                 0
# funded_amnt               0
# funded_amnt_inv         129
# term                      0
# int_rate                  0
# installment               0
# grade                     0
# sub_grade                 0
# emp_length             1075
# home_ownership            0
# annual_inc                0
# verification_status       0
# issue_d                   0
# loan_status               0
# dti                     183
# earliest_cr_line          0
# open_acc                  0
# revol_bal               994
# revol_util               50
# total_acc                 0
# total_pymnt              16
# total_pymnt_inv         165
# total_rec_prncp          74
# total_rec_int            71
# last_pymnt_d             71
# last_pymnt_amnt          74
# last_credit_pull_d        2
# application_type          0
# dtype: int64

# %%
col = df.columns

# %%
col
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'dti',
#        'earliest_cr_line', 'open_acc', 'revol_bal', 'revol_util', 'total_acc',
#        'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'application_type'],
#       dtype='object')

# %%
df
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0           5000         5000           4975.0   36 months   10.65%
# 1           2500         2500           2500.0   60 months   15.27%
# 2           2400         2400           2400.0   36 months   15.96%
# 3          10000        10000          10000.0   36 months   13.49%
# 4           3000         3000           3000.0   60 months   12.69%
# ...          ...          ...              ...         ...      ...
# 39712       2500         2500           1075.0   36 months    8.07%
# 39713       8500         8500            875.0   36 months   10.28%
# 39714       5000         5000           1325.0   36 months    8.07%
# 39715       5000         5000            650.0   36 months    7.43%
# 39716       7500         7500            800.0   36 months   13.75%
#
#        installment grade sub_grade emp_length home_ownership  ...  revol_util  \
# 0           162.87     B        B2  10+ years           RENT  ...      83.70%
# 1            59.83     C        C4   < 1 year           RENT  ...       9.40%
# 2            84.33     C        C5  10+ years           RENT  ...      98.50%
# 3           339.31     C        C1  10+ years           RENT  ...         21%
# 4            67.79     B        B5     1 year           RENT  ...      53.90%
# ...            ...   ...       ...        ...            ...  ...         ...
# 39712        78.42     A        A4    4 years       MORTGAGE  ...      13.10%
# 39713       275.38     C        C1    3 years           RENT  ...      26.90%
# 39714       156.84     A        A4   < 1 year       MORTGAGE  ...      19.40%
# 39715       155.38     A        A2   < 1 year       MORTGAGE  ...       0.70%
# 39716       255.43     E        E2   < 1 year            OWN  ...      51.50%
#
#       total_acc   total_pymnt total_pymnt_inv  total_rec_prncp total_rec_int  \
# 0             9   5863.155187         5833.84          5000.00        863.16
# 1             4   1008.710000         1008.71           456.46        435.17
# 2            10   3005.666844         3005.67          2400.00        605.67
# 3            37  12231.890000        12231.89         10000.00       2214.92
# 4            38   3513.330000         3513.33          2475.94       1037.39
# ...         ...           ...             ...              ...           ...
# 39712        40   2822.969293         1213.88          2500.00        322.97
# 39713         9   9913.491822         1020.51          8500.00       1413.49
# 39714        20   5272.161128         1397.12          5000.00        272.16
# 39715        26   5174.198551          672.66          5000.00        174.20
# 39716         8   9195.263334          980.83          7500.00       1695.26
#
#        last_pymnt_d  last_pymnt_amnt last_credit_pull_d  application_type
# 0            Jan-15           171.62             May-16        INDIVIDUAL
# 1            Apr-13           119.66             Sep-13        INDIVIDUAL
# 2            Jun-14           649.91             May-16        INDIVIDUAL
# 3            Jan-15           357.48             Apr-16        INDIVIDUAL
# 4            May-16            67.79             May-16        INDIVIDUAL
# ...             ...              ...                ...               ...
# 39712        Jul-10            80.90             Jun-10        INDIVIDUAL
# 39713        Jul-10           281.94             Jul-10        INDIVIDUAL
# 39714        Apr-08              NaN             Jun-07        INDIVIDUAL
# 39715        Jan-08              NaN             Jun-07        INDIVIDUAL
# 39716        Jun-10           256.59             Jun-10        INDIVIDUAL
#
# [39717 rows x 28 columns]

# %%
# now we we check these columns data, if they are not usefull we will remove it

# %%
df.loan_status.value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: loan_status, dtype: int64

# %%
# siince current status is nither Fully paid nor Charged-off we can remove that and do further analysis

# %%
# removing rows which has loan_status Current 
df = df[~(df.loan_status == "Current")]

# %%
df.shape
# Out:
# (38577, 28)

# %%
df.grade.value_counts()
# Out:
# B    11675
# A    10045
# C     7834
# D     5085
# E     2663
# F      976
# G      299
# Name: grade, dtype: int64

# %%
for i in col:
    print(i)
    print(df[i].value_counts())
    print("*****************")
# Out:
# loan_amnt
# 10000    2809
# 12000    2248
# 5000     2028
# 6000     1886
# 15000    1838
#          ...
# 18325       1
# 9650        1
# 20450       1
# 15425       1
# 22550       1
# Name: loan_amnt, Length: 870, dtype: int64
# *****************
# funded_amnt
# 10000    2719
# 12000    2161
# 5000     2017
# 6000     1876
# 15000    1732
#          ...
# 1650        1
# 30100       1
# 19675       1
# 21275       1
# 22350       1
# Name: funded_amnt, Length: 1019, dtype: int64
# *****************
# funded_amnt_inv
# 5000.00000     1294
# 10000.00000    1264
# 6000.00000     1182
# 12000.00000    1016
# 8000.00000      887
#                ...
# 24240.11000       1
# 16458.93000       1
# 18911.95000       1
# 8766.79000        1
# 9906.30791        1
# Name: funded_amnt_inv, Length: 8049, dtype: int64
# *****************
# term
#  36 months    29096
#  60 months     9481
# Name: term, dtype: int64
# *****************
# int_rate
# 10.99%    913
# 11.49%    790
# 7.51%     787
# 13.49%    749
# 7.88%     725
#          ...
# 16.96%      1
# 18.36%      1
# 16.15%      1
# 16.01%      1
# 16.20%      1
# Name: int_rate, Length: 370, dtype: int64
# *****************
# installment
# 311.11    68
# 180.96    59
# 311.02    54
# 150.80    48
# 368.45    46
#           ..
# 587.33     1
# 518.72     1
# 51.91      1
# 835.09     1
# 255.43     1
# Name: installment, Length: 15022, dtype: int64
# *****************
# grade
# B    11675
# A    10045
# C     7834
# D     5085
# E     2663
# F      976
# G      299
# Name: grade, dtype: int64
# *****************
# sub_grade
# A4    2873
# B3    2825
# A5    2715
# B5    2615
# B4    2437
# C1    2055
# B2    2001
# C2    1931
# A3    1810
# B1    1797
# A2    1508
# C3    1488
# D2    1286
# C4    1206
# C5    1154
# A1    1139
# D3    1116
# D1     931
# D4     918
# D5     834
# E1     722
# E2     614
# E3     516
# E4     424
# E5     387
# F1     305
# F2     233
# F3     174
# F4     151
# F5     113
# G1      94
# G2      77
# G4      54
# G3      45
# G5      29
# Name: sub_grade, dtype: int64
# *****************
# emp_length
# 10+ years    8488
# < 1 year     4508
# 2 years      4291
# 3 years      4012
# 4 years      3342
# 5 years      3194
# 1 year       3169
# 6 years      2168
# 7 years      1711
# 8 years      1435
# 9 years      1226
# Name: emp_length, dtype: int64
# *****************
# home_ownership
# RENT        18480
# MORTGAGE    17021
# OWN          2975
# OTHER          98
# NONE            3
# Name: home_ownership, dtype: int64
# *****************
# annual_inc
# 60000.0     1466
# 50000.0     1029
# 40000.0      855
# 45000.0      811
# 30000.0      808
#             ...
# 80569.0        1
# 82116.0        1
# 242400.0       1
# 133300.0       1
# 27376.0        1
# Name: annual_inc, Length: 5215, dtype: int64
# *****************
# verification_status
# Not Verified       16694
# Verified           12206
# Source Verified     9677
# Name: verification_status, dtype: int64
# *****************
# issue_d
# Nov-11    2062
# Dec-11    2042
# Oct-11    1941
# Sep-11    1913
# Aug-11    1798
# Jul-11    1745
# Jun-11    1728
# May-11    1609
# Apr-11    1559
# Mar-11    1442
# Jan-11    1380
# Feb-11    1297
# Dec-10    1267
# Oct-10    1132
# Nov-10    1121
# Jul-10    1119
# Sep-10    1086
# Aug-10    1078
# Jun-10    1029
# May-10     920
# Apr-10     827
# Mar-10     737
# Feb-10     627
# Nov-09     602
# Dec-09     598
# Jan-10     589
# Oct-09     545
# Sep-09     449
# Aug-09     408
# Jul-09     374
# Jun-09     356
# May-09     319
# Apr-09     290
# Mar-09     276
# Feb-09     260
# Jan-09     239
# Mar-08     236
# Dec-08     223
# Nov-08     184
# Feb-08     174
# Jan-08     171
# Apr-08     155
# Oct-08      96
# Dec-07      85
# Jul-08      83
# May-08      71
# Aug-08      71
# Jun-08      66
# Oct-07      47
# Nov-07      37
# Aug-07      33
# Sep-08      32
# Jul-07      30
# Sep-07      18
# Jun-07       1
# Name: issue_d, dtype: int64
# *****************
# loan_status
# Fully Paid     32950
# Charged Off     5627
# Name: loan_status, dtype: int64
# *****************
# dti
# 12.00    46
# 18.00    45
# 13.20    39
# 19.20    39
# 12.48    37
#          ..
# 28.95     1
# 25.85     1
# 25.77     1
# 27.20     1
# 25.43     1
# Name: dti, Length: 2852, dtype: int64
# *****************
# earliest_cr_line
# Oct-99    360
# Nov-98    357
# Oct-00    341
# Dec-98    340
# Dec-97    318
#          ...
# Nov-65      1
# Feb-73      1
# Oct-08      1
# Dec-61      1
# Oct-74      1
# Name: earliest_cr_line, Length: 524, dtype: int64
# *****************
# open_acc
# 7     3909
# 6     3846
# 8     3814
# 9     3607
# 5     3111
# 10    3097
# 11    2666
# 4     2300
# 12    2198
# 13    1855
# 3     1470
# 14    1427
# 15    1146
# 16     908
# 17     716
# 2      596
# 18     516
# 19     384
# 20     281
# 21     235
# 22     137
# 23      93
# 24      75
# 25      53
# 26      34
# 28      24
# 27      22
# 30      15
# 29      13
# 31       7
# 34       5
# 35       4
# 32       3
# 33       3
# 36       2
# 39       1
# 38       1
# 44       1
# 41       1
# 42       1
# Name: open_acc, dtype: int64
# *****************
# revol_bal
# 255.0      14
# 298.0      14
# 1.0        12
# 682.0      11
# 6.0         9
#            ..
# 36186.0     1
# 21450.0     1
# 38222.0     1
# 4236.0      1
# 85607.0     1
# Name: revol_bal, Length: 21274, dtype: int64
# *****************
# revol_util
# 0%        954
# 0.20%      62
# 63%        62
# 40.70%     57
# 31.20%     57
#          ...
# 77.63%      1
# 25.74%      1
# 0.83%       1
# 47.36%      1
# 7.28%       1
# Name: revol_util, Length: 1088, dtype: int64
# *****************
# total_acc
# 16    1424
# 15    1418
# 17    1411
# 14    1403
# 20    1390
#       ...
# 74       1
# 77       1
# 78       1
# 87       1
# 90       1
# Name: total_acc, Length: 82, dtype: int64
# *****************
# total_pymnt
# 11196.569430    26
# 10956.775960    16
# 11784.232230    16
# 13148.137860    15
# 5478.387981     15
#                 ..
# 12579.565870     1
# 13008.995020     1
# 32322.359970     1
# 1476.070000      1
# 9195.263334      1
# Name: total_pymnt, Length: 36713, dtype: int64
# *****************
# total_pymnt_inv
# 6514.52     16
# 13148.14    14
# 5478.39     14
# 10956.78    12
# 11196.57    12
#             ..
# 17947.76     1
# 3288.53      1
# 4172.43      1
# 340.70       1
# 980.83       1
# Name: total_pymnt_inv, Length: 36386, dtype: int64
# *****************
# total_rec_prncp
# 10000.00    2293
# 12000.00    1805
# 5000.00     1702
# 6000.00     1637
# 15000.00    1400
#             ...
# 5244.78        1
# 1958.25        1
# 4237.85        1
# 2556.60        1
# 16077.42       1
# Name: total_rec_prncp, Length: 6840, dtype: int64
# *****************
# total_rec_int
# 1196.57    26
# 514.52     19
# 1148.14    17
# 1784.23    17
# 717.95     17
#            ..
# 247.93      1
# 1652.61     1
# 2265.15     1
# 6418.48     1
# 1695.26     1
# Name: total_rec_int, Length: 34024, dtype: int64
# *****************
# last_pymnt_d
# Mar-13    1026
# Dec-14     945
# May-13     907
# Feb-13     869
# Apr-13     851
#           ...
# Jun-08      10
# Nov-08      10
# Mar-08       5
# Jan-08       4
# Feb-08       1
# Name: last_pymnt_d, Length: 101, dtype: int64
# *****************
# last_pymnt_amnt
# 200.00     17
# 50.00      15
# 100.00     15
# 400.00     12
# 150.00     11
#            ..
# 371.76      1
# 1331.29     1
# 2144.53     1
# 28.16       1
# 256.59      1
# Name: last_pymnt_amnt, Length: 34417, dtype: int64
# *****************
# last_credit_pull_d
# May-16    9333
# Apr-16    2393
# Mar-16    1122
# Feb-13     843
# Feb-16     733
#           ...
# May-08       1
# Jun-08       1
# Jul-08       1
# May-07       1
# Jul-07       1
# Name: last_credit_pull_d, Length: 106, dtype: int64
# *****************
# application_type
# INDIVIDUAL    38577
# Name: application_type, dtype: int64
# *****************

# %%
# since application_type has only 1 value we can drop that
df.drop(["application_type"], axis=1, inplace=True)
# Out:
# /var/folders/qc/gk_jrz1s3ln3dwkfp1yhtc3h0000gq/T/ipykernel_70562/4205798008.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(["application_type"], axis=1, inplace=True)

# %%
df.shape
# Out:
# (38577, 27)

# %%
# removing % from int_rate
df["int_rate"]= df.int_rate.apply(lambda x: float(x[:-1]))
# Out:
# /var/folders/qc/gk_jrz1s3ln3dwkfp1yhtc3h0000gq/T/ipykernel_70562/3580903915.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["int_rate"]= df.int_rate.apply(lambda x: float(x[:-1]))

# %%
df.int_rate
# Out:
# 0        10.65
# 1        15.27
# 2        15.96
# 3        13.49
# 5         7.90
#          ...
# 39712     8.07
# 39713    10.28
# 39714     8.07
# 39715     7.43
# 39716    13.75
# Name: int_rate, Length: 38577, dtype: float64

# %%
df['int_rate'].describe()
# Out:
# count    38577.000000
# mean        11.932219
# std          3.691327
# min          5.420000
# 25%          8.940000
# 50%         11.710000
# 75%         14.380000
# max         24.400000
# Name: int_rate, dtype: float64

# %%
plt.boxplot(df.int_rate)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x3359dc2d0>,
#   <matplotlib.lines.Line2D at 0x3359dce10>],
#  'caps': [<matplotlib.lines.Line2D at 0x3359dd790>,
#   <matplotlib.lines.Line2D at 0x3359de110>],
#  'boxes': [<matplotlib.lines.Line2D at 0x334738fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x3359de890>],
#  'fliers': [<matplotlib.lines.Line2D at 0x3359dc290>],
#  'means': []}

# %%
df['installment'].describe()
# Out:
# count    38577.000000
# mean       322.466318
# std        208.639215
# min         15.690000
# 25%        165.740000
# 50%        277.860000
# 75%        425.550000
# max       1305.190000
# Name: installment, dtype: float64

# %%
plt.boxplot(df.installment)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x32a4b6d50>,
#   <matplotlib.lines.Line2D at 0x332eb9a10>],
#  'caps': [<matplotlib.lines.Line2D at 0x332d7d8d0>,
#   <matplotlib.lines.Line2D at 0x332fc7c90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x32a4a5fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x33482ea50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x332ed6a90>],
#  'means': []}

# %%
df.groupby('loan_status')['installment'].describe()
# Out:
#                count        mean         std    min       25%     50%  \
# loan_status
# Charged Off   5627.0  336.175006  217.051841  22.79  168.5550  293.87
# Fully Paid   32950.0  320.125232  207.081110  15.69  165.2825  275.65
#
#                  75%      max
# loan_status
# Charged Off  457.840  1305.19
# Fully Paid   420.735  1295.21

# %%
sns.boxplot(x="installment", y="loan_status",data=df)
# from this graph we see that no of installment for charged of is higher that fully paid
# Out:
# <Axes: xlabel='installment', ylabel='loan_status'>

# %%
df.groupby('loan_status')['int_rate'].describe()
# Out:
#                count       mean       std   min    25%    50%    75%    max
# loan_status
# Charged Off   5627.0  13.820432  3.654413  5.42  11.31  13.61  16.40  24.40
# Fully Paid   32950.0  11.609761  3.599964  5.42   8.49  11.49  13.99  24.11

# %%
sns.boxplot(x="int_rate", y="loan_status",data=df)
# from this graph we see that charged-off have intrest rate higher
# Out:
# <Axes: xlabel='int_rate', ylabel='loan_status'>

# %%
pd.crosstab(df['grade'], df['loan_status'])
# we see that person who has a good grade has good change that they will have Fully paid status
# Out:
# loan_status  Charged Off  Fully Paid
# grade
# A                    602        9443
# B                   1425       10250
# C                   1347        6487
# D                   1118        3967
# E                    715        1948
# F                    319         657
# G                    101         198

# %%
pd.crosstab(df['grade'],df['loan_status']).plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='grade'>

# %%
sns.boxplot(x="loan_amnt", y="loan_status",data=df)
# Out:
# <Axes: xlabel='loan_amnt', ylabel='loan_status'>

# %%
df.groupby('loan_status')['loan_amnt'].describe()
# here we see that loan_amt for Charged_off is higher
# Out:
#                count          mean          std    min     25%      50%  \
# loan_status
# Charged Off   5627.0  12104.385108  8085.732038  900.0  5600.0  10000.0
# Fully Paid   32950.0  10866.455994  7199.629493  500.0  5200.0   9600.0
#
#                  75%      max
# loan_status
# Charged Off  16500.0  35000.0
# Fully Paid   15000.0  35000.0

# %%
pd.crosstab(df['home_ownership'],df['loan_status'])
# Out:
# loan_status     Charged Off  Fully Paid
# home_ownership
# MORTGAGE               2327       14694
# NONE                      0           3
# OTHER                    18          80
# OWN                     443        2532
# RENT                   2839       15641

# %%
df.home_ownership.value_counts()
# Out:
# RENT        18480
# MORTGAGE    17021
# OWN          2975
# OTHER          98
# NONE            3
# Name: home_ownership, dtype: int64

# %%
df.groupby('home_ownership')['loan_status'].value_counts().loc[:,'Charged Off'].plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='home_ownership'>

# %%
df.groupby('home_ownership')['loan_status'].value_counts().loc[:,'Fully Paid'].plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='home_ownership'>

# %%
# with home_ownership we can't identity much

# %%
df.groupby('term')['loan_status'].value_counts().loc[:,'Charged Off'].plot(kind="bar",stacked=True)
# from this we can see that person who has term, 36 months are more defaulted
# Out:
# <Axes: xlabel='term'>

# %%
pd.crosstab(df['term'],df['loan_status'])
# Out:
# loan_status  Charged Off  Fully Paid
# term
#  36 months          3227       25869
#  60 months          2400        7081

# %%
df.application_type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[425], line 1
# ----> 1 df.application_type
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'application_type'

# %%
df1 = df[df.loan_status=="Charged Off"]

# %%
df1.verification_status.value_counts()
# Out:
# Not Verified       2142
# Verified           2051
# Source Verified    1434
# Name: verification_status, dtype: int64

# %%
df.groupby('verification_status')['loan_status'].value_counts().loc[:,'Charged Off'].plot(kind="bar",stacked=True)
# here we see that Not Verified and Verified both varification status can be defaulted
# Out:
# <Axes: xlabel='verification_status'>

# %%
df.annual_inc.describe()
# Out:
# count    3.857700e+04
# mean     6.877797e+04
# std      6.421868e+04
# min      4.000000e+03
# 25%      4.000000e+04
# 50%      5.886800e+04
# 75%      8.200000e+04
# max      6.000000e+06
# Name: annual_inc, dtype: float64

# %%
# let's dive annual_inc in bucket
df.annual_inc.sort_values()
# Out:
# 35501       4000.0
# 29283       4080.0
# 37709       4200.0
# 30726       4200.0
# 36639       4800.0
#            ...
# 7247     1782000.0
# 23551    1900000.0
# 39089    2039784.0
# 29639    3900000.0
# 30107    6000000.0
# Name: annual_inc, Length: 38577, dtype: float64

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0       5000         5000           4975.0   36 months     10.65       162.87
# 1       2500         2500           2500.0   60 months     15.27        59.83
# 2       2400         2400           2400.0   36 months     15.96        84.33
# 3      10000        10000          10000.0   36 months     13.49       339.31
# 5       5000         5000           5000.0   36 months      7.90       156.46
#
#   grade sub_grade emp_length home_ownership  ...  revol_util total_acc  \
# 0     B        B2  10+ years           RENT  ...      83.70%         9
# 1     C        C4   < 1 year           RENT  ...       9.40%         4
# 2     C        C5  10+ years           RENT  ...      98.50%        10
# 3     C        C1  10+ years           RENT  ...         21%        37
# 5     A        A4    3 years           RENT  ...      28.30%        12
#
#     total_pymnt total_pymnt_inv  total_rec_prncp total_rec_int  last_pymnt_d  \
# 0   5863.155187         5833.84          5000.00        863.16        Jan-15
# 1   1008.710000         1008.71           456.46        435.17        Apr-13
# 2   3005.666844         3005.67          2400.00        605.67        Jun-14
# 3  12231.890000        12231.89         10000.00       2214.92        Jan-15
# 5   5632.210000         5632.21          5000.00        632.21        Jan-15
#
#    last_pymnt_amnt last_credit_pull_d  IncomeBucket
# 0           171.62             May-16            VL
# 1           119.66             Sep-13            VL
# 2           649.91             May-16            VL
# 3           357.48             Apr-16             L
# 5           161.03             Jan-16            VL
#
# [5 rows x 28 columns]

# %%
plt.boxplot(df.annual_inc)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x32ac75210>,
#   <matplotlib.lines.Line2D at 0x32ac75c10>],
#  'caps': [<matplotlib.lines.Line2D at 0x32ac76610>,
#   <matplotlib.lines.Line2D at 0x32ac76dd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x32aa28a10>],
#  'medians': [<matplotlib.lines.Line2D at 0x32ac77550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x32ac77d50>],
#  'means': []}

# %%
# remove outliers from annual_inc
df = df[(df.annual_inc < 1000000)]

# %%
sns.boxplot(y="annual_inc", x="loan_status",data=df)
# Out:
# <Axes: xlabel='loan_status', ylabel='annual_inc'>

# %%
df.groupby('loan_status')['annual_inc'].describe()
# Out:
#                count          mean           std     min      25%      50%  \
# loan_status
# Charged Off   5626.0  62216.211525  45079.747234  4080.0  37000.0  53000.0
# Fully Paid   32937.0  69116.486039  47740.334581  4000.0  41056.0  60000.0
#
#                  75%       max
# loan_status
# Charged Off  75000.0  840000.0
# Fully Paid   84000.0  948000.0

# %%
df["IncomeBucket"] = pd.qcut(df['annual_inc'],[0,0.2,0.4,0.6,0.8,1],["VL","L","M","H","VH"])

# %%
df.groupby('IncomeBucket')['loan_status'].value_counts().loc[:,'Charged Off'].plot(kind="bar",stacked=True)
# from this we see that lower the annual income higher the Charged-off
# Out:
# <Axes: xlabel='IncomeBucket'>

# %%
# issue_d
df["issue_year"] = df.issue_d.apply(lambda x: int("20"+x[-2:]))
df["issue_month"] = df.issue_d.apply(lambda x: x[:3])

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0       5000         5000           4975.0   36 months     10.65       162.87
# 1       2500         2500           2500.0   60 months     15.27        59.83
# 2       2400         2400           2400.0   36 months     15.96        84.33
# 3      10000        10000          10000.0   36 months     13.49       339.31
# 5       5000         5000           5000.0   36 months      7.90       156.46
#
#   grade sub_grade emp_length home_ownership  ...   total_pymnt  \
# 0     B        B2  10+ years           RENT  ...   5863.155187
# 1     C        C4   < 1 year           RENT  ...   1008.710000
# 2     C        C5  10+ years           RENT  ...   3005.666844
# 3     C        C1  10+ years           RENT  ...  12231.890000
# 5     A        A4    3 years           RENT  ...   5632.210000
#
#   total_pymnt_inv total_rec_prncp total_rec_int  last_pymnt_d last_pymnt_amnt  \
# 0         5833.84         5000.00        863.16        Jan-15          171.62
# 1         1008.71          456.46        435.17        Apr-13          119.66
# 2         3005.67         2400.00        605.67        Jun-14          649.91
# 3        12231.89        10000.00       2214.92        Jan-15          357.48
# 5         5632.21         5000.00        632.21        Jan-15          161.03
#
#    last_credit_pull_d  IncomeBucket issue_year  issue_month
# 0              May-16            VL       2011          Dec
# 1              Sep-13            VL       2011          Dec
# 2              May-16            VL       2011          Dec
# 3              Apr-16             L       2011          Dec
# 5              Jan-16            VL       2011          Dec
#
# [5 rows x 30 columns]

# %%
df.groupby('issue_year')['loan_status'].value_counts().loc[:,'Charged Off'].plot(kind="bar",stacked=True)
# here we can notice that Charged-off suddenly increased very much in 2011
# Out:
# <Axes: xlabel='issue_year'>

# %%
df.groupby('issue_month')['loan_status'].value_counts().loc[:,'Charged Off'].plot(kind="bar",stacked=True)
# here we can notice that Charged-off suddenly increased very much in month of Dec
# Out:
# <Axes: xlabel='issue_month'>

# %%
# bedit to income ratio
df.dti.describe()
# Out:
# count    38386.000000
# mean        13.337772
# std          6.624348
# min          0.010000
# 25%          8.210000
# 50%         13.410000
# 75%         18.580000
# max         29.990000
# Name: dti, dtype: float64

# %%
df.groupby('loan_status')['dti'].describe()
# Out:
#                count       mean       std   min   25%    50%    75%    max
# loan_status
# Charged Off   5597.0  14.071771  6.524611  0.01  9.15  14.34  19.30  29.85
# Fully Paid   32789.0  13.212480  6.633211  0.01  8.06  13.24  18.43  29.99

# %%
sns.boxplot(x="loan_status", y="dti",data=df)
# from this we can see that higher the dti higher the Charged-off
# Out:
# <Axes: xlabel='loan_status', ylabel='dti'>

# %%
# conclusion


# Charged-off highly depends on factors like int_rate, grade, loan_amnt, term, annual_inc, issue_year, dti .
# more these factor higher the chances of Defaulted
